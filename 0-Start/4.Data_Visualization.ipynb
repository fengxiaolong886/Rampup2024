# %% [markdown]
# https://github.com/jackfrued/Python-100-Days/blob/master/Day66-80/78.%E6%95%B0%E6%8D%AE%E5%8F%AF%E8%A7%86%E5%8C%96-1.md

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %config InlineBackend.figure_format='svg'

# %%
plt.figure(figsize=(8, 4), dpi = 120, facecolor="darkgray")

# %%
plt.subplot(2,2,1)
# Out:
# <Axes: >

# %%
import numpy as np

x = np.linspace(-2 * np.pi, 2 * np.pi, 120)
y = np.sin(x)

# 创建画布
plt.figure(figsize=(8, 4), dpi=120, facecolor="blue")
# 绘制折线图
plt.plot(x, y, linewidth=2, marker='*', color='red')
# 显示绘图
plt.show()

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 120)
y1, y2  = np.sin(x), np.cos(x)

# 创建画布
plt.figure(figsize=(8, 4), dpi=120, facecolor="blue")
# 绘制折线图
plt.plot(x, y1, linewidth=2, marker='*', color='red')
plt.plot(x, y2, linewidth=2, marker='*', color='green')

plt.annotate('sin(x)', xytext=(0.5, -0.75), xy=(0, -0.25), fontsize=12, arrowprops={
    'arrowstyle': '->', 'color': 'red', 'connectionstyle': 'angle3, angleA=90, angleB=0'
})
plt.annotate('cos(x)', xytext=(-3, 0.75), xy=(-1.25, 0.5), fontsize=12, arrowprops={
    'arrowstyle': '->', 'color': 'darkgreen', 'connectionstyle': 'arc3, rad=0.35'
})
# 显示绘图
plt.show()

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 120)
y1, y2  = np.sin(x), np.cos(x)

# 创建画布
plt.figure(figsize=(8, 4), dpi=120, facecolor="blue")
# 绘制折线图
plt.subplot(2,1,1)
plt.plot(x, y1, linewidth=2, marker='*', color='red')
plt.subplot(2,1,2)
plt.plot(x, y2, linewidth=2, marker='*', color='green')

# 显示绘图
plt.show()

# %%
plt.figure(figsize=(8, 4), dpi=120)
plt.subplot(1, 2, 1)
plt.plot(x, y1, linewidth=2, marker='*', color='red')
plt.subplot(1, 2, 2)
plt.plot(x, y2, linewidth=2, marker='^', color='blue')
plt.show()

# %%
fig = plt.figure(figsize=(10, 4), dpi=120)
plt.plot(x, y1, linewidth=2, marker='*', color='red')
# 用Figure对象的add_axes方法在现有坐标系中嵌套一个新的坐标系，该方法的参数是一个四元组，
# 代表了新坐标系在原坐标系中的位置，前两个值是左下角的位置，后两个值是坐标系的宽度和高度
ax = fig.add_axes((0.595, 0.6, 0.3,0.25))
ax.plot(x, y2, marker='^', color='blue')
ax = fig.add_axes((0.155, 0.2, 0.3,0.25))
ax.plot(x, y2, marker='^', color='green')
plt.show()

# %%
x = np.array([5550, 7500, 10500, 15000, 20000, 25000, 30000, 40000])
y = np.array([800, 1800, 1250, 2000, 1800, 2100, 2500, 3500])

plt.figure(figsize=(6, 4), dpi=120, facecolor="orange")
plt.scatter(x, y)
plt.show()

# %%
x = np.arange(4)
y1 = np.random.randint(20, 50, 4)
y2 = np.random.randint(10, 60, 4)
plt.figure(figsize=(6, 4), dpi=120, facecolor="orange")
# 通过横坐标的偏移，让两组数据对应的柱子分开，width参数控制柱子的粗细，label参数为柱子添加标签
plt.bar(x - 0.1, y1, width=0.2, label='A')
plt.bar(x + 0.1, y2, width=0.2, label='B')
# 定制横轴的刻度
plt.xticks(x, labels=['Q1', 'Q2', 'Q3', 'Q4'])
# 定制显示图例
plt.legend()
plt.show()

# %%
labels = ['Q1', 'Q2', 'Q3', 'Q4']
plt.figure(figsize=(6, 4), dpi=120)
plt.bar(labels, y1, width=0.4, label='销售A组')
# 注意：堆叠柱状图的关键是将之前的柱子作为新柱子的底部，可以通过bottom参数指定底部数据，新柱子绘制在底部数据之上
plt.bar(labels, y2, width=0.4, bottom=y1, label='销售B组')
plt.legend(loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 38144 (\N{CJK UNIFIED IDEOGRAPH-9500}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21806 (\N{CJK UNIFIED IDEOGRAPH-552E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32452 (\N{CJK UNIFIED IDEOGRAPH-7EC4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data = np.random.randint(100, 500, 7)
labels = ['apple', 'orange', 'peach', 'pears', 'banana', 'watemelo', 'cherry']

plt.figure(figsize=(5, 5), dpi=120, facecolor="purple")
plt.pie(
    data,
    # 自动显示百分比
    autopct='%.1f%%',
    # 饼图的半径
    radius=1,
    # 百分比到圆心的距离
    pctdistance=0.8
    +,
    # 颜色（随机生成）
    colors=np.random.rand(7, 3),
    # 分离距离
    # explode=[0.05, 0, 0.1, 0, 0, 0, 0],
    # 阴影效果
    # shadow=True,
    # 字体属性
    textprops=dict(fontsize=8, color='black'),
    # 楔子属性（生成环状饼图的关键）
    wedgeprops=dict(linewidth=1, width=0.35),
    # 标签
    labels=labels
)
# 定制图表的标题
plt.title('Sales')
plt.show()

# %%
heights = np.array([
    170, 163, 174, 164, 159, 168, 165, 171, 171, 167, 
    165, 161, 175, 170, 174, 170, 174, 170, 173, 173, 
    167, 169, 173, 153, 165, 169, 158, 166, 164, 173, 
    162, 171, 173, 171, 165, 152, 163, 170, 171, 163, 
    165, 166, 155, 155, 171, 161, 167, 172, 164, 155, 
    168, 171, 173, 169, 165, 162, 168, 177, 174, 178, 
    161, 180, 155, 155, 166, 175, 159, 169, 165, 174, 
    175, 160, 152, 168, 164, 175, 168, 183, 166, 166, 
    182, 174, 167, 168, 176, 170, 169, 173, 177, 168, 
    172, 159, 173, 185, 161, 170, 170, 184, 171, 172
])

# %%
plt.figure(figsize=(6, 4), dpi=120, facecolor="purple")
# 绘制直方图
plt.hist(heights, bins=np.arange(145, 196, 5), color='darkcyan', density=True, cumulative=True)
# 定制横轴标签
plt.xlabel('Heights')
# 定制纵轴标签
plt.ylabel('Probability')
plt.show()

# %%
plt.figure(figsize=(6, 4), dpi=120, facecolor="purple")
# 绘制直方图
plt.hist(heights, bins=np.arange(145, 196, 5), color="darkcyan")
# 定制横轴标签
plt.xlabel('Heights')
# 定制纵轴标签
plt.ylabel('Probability')
plt.show()

# %%
data = np.random.randint(0, 100, 100)
data = np.append(data, 160)
data = np.append(data, 200)
data = np.append(data, -50)

plt.figure(figsize=(6, 4), dpi=120, facecolor="blue")
plt.boxplot(data, whis=1.5, showmeans=True, notch=True)
plt.ylim([-100,250])
plt.xticks([1], labels = ["data"])
plt.savefig("./Test_Data/Img/boxplot.jpg")
plt.show()

# %%
income = np.array([5550, 7500, 10500, 15000, 20000, 25000, 30000, 40000])
outcome = np.array([800, 1800, 1250, 2000, 1800, 2100, 2500, 3500])
nums = np.array([5, 3, 10, 5, 12, 20, 8, 10])

plt.scatter(income, outcome, s = nums * 30, c = nums, cmap = "Blues")
plt.colorbar()
plt.savefig("./Test_Data/Img/Scatter.jpg")
plt.show()

# %%
plt.figure(figsize=(8, 4))
days = np.arange(7)
sleeping = [7, 8, 6, 6, 7, 8, 10]
eating = [2, 3, 2, 1, 2, 3, 2]
working = [7, 8, 7, 8, 6, 2, 3]
playing = [8, 5, 9, 9, 9, 11, 9]
plt.stackplot(days, sleeping, eating, working, playing)
plt.xticks(days, labels=[f"D{x}" for x in range(7)])
plt.legend(["Sleep","Eat", "Work", "Play"], fontsize = 10)
plt.savefig("./Test_Data/Img/stackplot.jpg")
plt.show()

# %%
labels = np.array(['Speed', 'Power', 'Experience', 'Defend', 'Kick', 'Tech'])
malong_values = np.array([93, 95, 98, 92, 96, 97])
shuigu_values = np.array([30, 40, 65, 80, 45, 60])

angles = np.linspace(0, 2* np.pi, labels.size, endpoint=False)
malong_values = np.append(malong_values, malong_values[0])
shuigu_values = np.append(shuigu_values, shuigu_values[0])
angles = np.append(angles, angles[0])
plt.figure(figsize=(4, 4), dpi=120)

ax = plt.subplot(projection='polar')

plt.plot(angles, malong_values, color='r', linewidth=2, label='Malong')
plt.fill(angles, malong_values, color='r', alpha=0.3)
plt.plot(angles, shuigu_values, color='g', linewidth=2, label='ShuiGU')
plt.fill(angles, shuigu_values, color='g', alpha=0.2)

plt.legend()
plt.savefig("./Test_Data/Img/polar.jpg")
plt.show()

# %%
group1 = np.random.randint(20, 50, 4)
group2 = np.random.randint(10, 60, 4)
x = np.array([f'A Team-Q{i}' for i in range(1, 5)] + [f'B Team-Q{i}' for i in range(1, 5)])
y = np.array(group1.tolist() + group2.tolist())
# 玫瑰花瓣的角度和宽度
theta = np.linspace(0, 2 * np.pi, x.size, endpoint=False)
width = 2 * np.pi / x.size
# 生成8种随机颜色
colors = np.random.rand(8, 3)
# 将柱状图投影到极坐标
ax = plt.subplot(projection='polar')
# 绘制柱状图
plt.bar(theta, y, width=width, color=colors, bottom=0)
# 设置网格
ax.set_thetagrids(theta * 180 / np.pi, x, fontsize=10)
# 显示图表
plt.savefig("./Test_Data/Img/Rose.jpg")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 4), dpi=120)
# 创建3D坐标系并添加到画布上
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)
x, y = np.meshgrid(x, y)
z = (1 - y ** 5 + x ** 5) * np.exp(-x ** 2 - y ** 2)
# 绘制3D曲面
ax.plot_surface(x, y, z)
# 显示图表
plt.savefig("./Test_Data/Img/3D.jpg")
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
sns.set_theme()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'].insert(0, 'SimHei')
plt.rcParams['axes.unicode_minus'] = False

# %%
tips_df = sns.load_dataset("tips")
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.histplot(data =tips_df, x = "total_bill", kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.pairplot(data = tips_df, hue = "sex")

# %%
sns.pairplot(data=tips_df, hue='sex', palette='Dark2')

# %%
sns.jointplot(data=tips_df, x='total_bill', y='tip', hue='sex')

# %%
sns.lmplot(data=tips_df, x='total_bill', y='tip', hue='sex')

# %%
sns.boxplot(data=tips_df, x='day', y='total_bill', palette='Dark2')
# Out:
# /tmp/ipykernel_127070/2041223270.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips_df, x='day', y='total_bill', palette='Dark2')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips_df, x='day', y='total_bill', palette='Dark2')
# Out:
# /tmp/ipykernel_127070/2537535065.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=tips_df, x='day', y='total_bill', palette='Dark2')
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Pyecharts

# %%
import pyecharts

# %%
from pyecharts.globals import CurrentConfig, NotebookType

CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts


# 创建柱状图对象并设置初始参数（宽度、高度）
bar_chart = Bar(init_opts=opts.InitOpts(width='600px', height='450px'))
# 设置横轴数据
bar_chart.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
# 设置纵轴数据（第一组）
bar_chart.add_yaxis("商家A", [25, 20, 36, 10, 75, 90])
# 设置纵轴数据（第二组）
bar_chart.add_yaxis("商家B", [15, 12, 30, 20, 45, 60])
# 设置纵轴数据（第三组）
bar_chart.add_yaxis("商家C", [12, 32, 40, 52, 35, 26])
# 添加全局配置参数
bar_chart.set_global_opts(
    # 横轴相关的参数
    xaxis_opts=opts.AxisOpts(
        axislabel_opts=opts.LabelOpts(color='navy')
    ),
    # 纵轴相关的参数（标签、最小值、最大值、间隔）
    yaxis_opts=opts.AxisOpts(
        axislabel_opts=opts.LabelOpts(color='navy'),
        min_=0,
        max_=100,
        interval=10
    ),
    # 标题相关的参数（内容、链接、位置、文本样式）
    title_opts=opts.TitleOpts(
        title='2022年销售数据展示',
        pos_left='2%',
        title_textstyle_opts=opts.TextStyleOpts(
            color='navy',
            font_size=16,
            font_family='苹方-简',
            font_weight='bold'
        )
    ),
    # 工具箱相关的参数
    toolbox_opts=opts.ToolboxOpts(
        orient='vertical',
        pos_left='right'
    )
)
# 加载绘图需要的JavaScript文件
bar_chart.load_javascript()

# %%
bar_chart.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="e7bcf1a2289d495b82fd034a5668f7e2" class="chart-container" style="width:600px; height:450px; "></div>
#     <script>
#         var chart_e7bcf1a2289d495b82fd034a5668f7e2 = echarts.init(
#             document.getElementById('e7bcf1a2289d495b82fd034a5668f7e2'), 'white', {renderer: 'canvas'});
#         var option_e7bcf1a2289d495b82fd034a5668f7e2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 25,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 15,
#                 12,
#                 30,
#                 20,
#                 45,
#                 60
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "legendHoverLink": true,
#             "data": [
#                 12,
#                 32,
#                 40,
#                 52,
#                 35,
#                 26
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "color": "navy",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "interval": 10,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "color": "navy",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 100,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "2022\u5e74\u9500\u552e\u6570\u636e\u5c55\u793a",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "2%",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "color": "navy",
#                 "fontWeight": "bold",
#                 "fontFamily": "\u82f9\u65b9-\u7b80",
#                 "fontSize": 16
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "right",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",

# %%
import pyecharts.options as opts
from pyecharts.charts import Pie

# 准备饼图需要的数据
x_data = ["直接访问", "邮件营销", "联盟广告", "视频广告", "搜索引擎"]
y_data = [335, 310, 234, 135, 1548]
data = [(x, y) for x, y in zip(x_data, y_data)]

# 创建饼图对象并设置初始化参数
pie_chart = Pie(init_opts=opts.InitOpts(width="800px", height="400px"))
# 向饼图添加数据
pie_chart.add(
    '', 
    data_pair=data,
    radius=["50%", "75%"],
    label_opts=opts.LabelOpts(is_show=False),
)
# 设置全局配置项
pie_chart.set_global_opts(
    # 配置图例相关的参数
    legend_opts=opts.LegendOpts(
        pos_left="legft",
        orient="vertical"
    )
)
# 设置数据系列配置参数
pie_chart.set_series_opts(
    # 设置不显示工具提示
    tooltip_opts=opts.TooltipOpts(is_show=False),
    # 设置饼图标签的样式
    label_opts=opts.LabelOpts(formatter="{b}({c}): {d}%")
)
pie_chart.load_javascript()

# %%
pie_chart.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="331a0138ffde43b0bb781be38dc9f9f3" class="chart-container" style="width:800px; height:400px; "></div>
#     <script>
#         var chart_331a0138ffde43b0bb781be38dc9f9f3 = echarts.init(
#             document.getElementById('331a0138ffde43b0bb781be38dc9f9f3'), 'white', {renderer: 'canvas'});
#         var option_331a0138ffde43b0bb781be38dc9f9f3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u76f4\u63a5\u8bbf\u95ee",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u90ae\u4ef6\u8425\u9500",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u8054\u76df\u5e7f\u544a",
#                     "value": 234
#                 },
#                 {
#                     "name": "\u89c6\u9891\u5e7f\u544a",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u641c\u7d22\u5f15\u64ce",
#                     "value": 1548
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}({c}): {d}%"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "tooltip": {
#                 "show": false,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "enterable": false,
#                 "confine": false,
#                 "appendToBody": false,
#                 "transitionDuration": 0.4,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5,
#                 "order": "seriesAsc"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f4\u63a5\u8bbf\u95ee",
#                 "\u90ae\u4ef6\u8425\u9500",
#                 "\u8054\u76df\u5e7f\u544a",
#                 "\u89c6\u9891\u5e7f\u544a",
#                 "\u641c\u7d22\u5f15\u64ce"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "legft",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_331a0138ffde43b0bb781be38dc9f9f3.setOption(option_331a0138ffde43b0bb781be38dc9f9f3);
#     </script>
# </body>
# </html>

# %%
data = [
    ('广东', 594), ('浙江', 438), ('四川', 316), ('北京', 269), ('山东', 248),
    ('江苏', 234), ('湖南', 196), ('福建', 166), ('河南', 153), ('辽宁', 152),
    ('上海', 138), ('河北', 86), ('安徽', 79), ('湖北', 75), ('黑龙江', 70), 
    ('陕西', 63), ('吉林', 59), ('江西', 56), ('重庆', 46), ('贵州', 39),
    ('山西', 37), ('云南', 33), ('广西', 24), ('天津', 22), ('新疆', 21),
    ('海南', 18), ('内蒙古', 14), ('台湾', 11), ('甘肃', 7), ('广西壮族自治区', 4),
    ('香港', 4), ('青海', 3), ('新疆维吾尔自治区', 3), ('内蒙古自治区', 3), ('宁夏', 1)
]

import pyecharts.options as opts
from pyecharts.charts import Map

map_chart = Map(init_opts=opts.InitOpts(width='1000px', height='1000px'))
map_chart.add('', data, 'china', is_roam=False)
map_chart.load_javascript()

# %%
map_chart.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="598f8c3fd7da440a944a9787fa6b69f7" class="chart-container" style="width:1000px; height:1000px; "></div>
#     <script>
#         var chart_598f8c3fd7da440a944a9787fa6b69f7 = echarts.init(
#             document.getElementById('598f8c3fd7da440a944a9787fa6b69f7'), 'white', {renderer: 'canvas'});
#         var option_598f8c3fd7da440a944a9787fa6b69f7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 594
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 438
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 316
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 269
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 248
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 234
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 196
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 166
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 153
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 152
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 63
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 59
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 1
#                 }
#             ],
#             "roam": false,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#         chart_598f8c3fd7da440a944a9787fa6b69f7.setOption(option_598f8c3fd7da440a944a9787fa6b69f7);
#     </script>
# </body>
# </html>
